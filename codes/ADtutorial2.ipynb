# %% [markdown]
# # Intro to Anomaly Detection with PyOD and ADbench

# %% [markdown]
# *Written by Joshua Harvey, for Prospect 33, 2024.*

# %% [markdown]
# Anomaly detection involves identifying observations that deviate significantly from the norm. It is a key component of data quality processes (DQ), along with missing value imputation and data drift.
#
# PyOD is a comprehensive library for detecting outliers in multivariate data. It provides various algorithms and utilities for anomaly detection.
#
# ADbench is a set of benchmark datasets pooled from a large number of published papers and previously used open-source datasets. For this notebook, we are only using the ADbench datasets, so these can be downloaded separately if you have issues with installing ADbench (eg dependency clashes).
#
# Shap is a library for implementing the SHAP (Shapley Additive exPlanations) explainability framework. It provides both model-specific and model-agnostic approaches for ML explainability.

# %% [markdown]
# ## 1. Setup and Installation
# Let's start by installing the required libraries. It is strongly recommended to build inside a dedicated environment.

# %%
# %pip install pyod adbench matplotlib seaborn shap
# Out:
# Collecting pyod
#   Downloading pyod-2.0.1.tar.gz (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting adbench
#   Downloading adbench-0.1.11-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Collecting shap
#   Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pyod) (1.4.2)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.25.2)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.10/dist-packages (from pyod) (0.58.1)
# Requirement already satisfied: scipy>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.2.2)
# Collecting pyod
#   Downloading pyod-1.0.0.tar.gz (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.8/118.8 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rtdl (from adbench)
#   Downloading rtdl-0.0.13-py3-none-any.whl (23 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from adbench) (2.3.0+cu121)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from adbench) (2.15.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from adbench) (2.15.0)
# Collecting delu (from adbench)
#   Downloading delu-0.0.23-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from adbench) (4.1.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from adbench) (2.0.3)
# Collecting catboost (from adbench)
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 4.7 MB/s eta 0:00:00
# Collecting copulas (from adbench)
#   Downloading copulas-0.11.0-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.7 MB/s eta 0:00:00
# Collecting combo (from adbench)
#   Downloading combo-0.1.3.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting barbar (from adbench)
#   Downloading barbar-0.2.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from adbench) (2023.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from adbench) (4.66.4)
# Collecting wget (from adbench)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyod) (1.16.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from pyod) (0.14.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.0.3)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51->pyod) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->pyod) (3.5.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost->adbench) (0.20.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost->adbench) (5.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->adbench) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->adbench) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->adbench) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->adbench) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->adbench) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->adbench)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->adbench)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->adbench)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->adbench)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->adbench)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->adbench)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->adbench)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->adbench)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->adbench)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->adbench)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->adbench)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->adbench) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->adbench)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 43.3 MB/s eta 0:00:00
# Collecting torch (from adbench)
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch->adbench)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 56.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch->adbench)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch->adbench)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch->adbench)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 62.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->adbench) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->adbench) (0.43.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->pyod) (0.5.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (3.20.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->adbench) (2.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost->adbench) (8.4.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->adbench) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->adbench) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->adbench) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->adbench) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->adbench) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->adbench) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->adbench) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->adbench) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->adbench) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->adbench) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->adbench) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->adbench) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->adbench) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->adbench) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->adbench) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->adbench) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->adbench) (3.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->adbench) (1.3.0)
# Building wheels for collected packages: pyod, combo, wget
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.0.0-py3-none-any.whl size=144444 sha256=fb76e10d5f7f20e7d8e5caf52de315435462d483a5503ac0b2313eba2adc6bfd
#   Stored in directory: /root/.cache/pip/wheels/bb/68/66/62e5ed97ce9d4dcdc3c1e60b24b5b438a2e052e9976c232d67
#   Building wheel for combo (setup.py) ... done
#   Created wheel for combo: filename=combo-0.1.3-py3-none-any.whl size=42861 sha256=1cf82ba4fd36ad6db9842d5b36af25852ca2a8c566c4f300aedc4f3c0797d00c
#   Stored in directory: /root/.cache/pip/wheels/7a/48/ff/0d6e1017d8bf3d844d332736fbb268dca767162779f93ff50a
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=2d914fb5dd3e9f7318cdc08039e178d07b23ad13b724aa6cdd101e1c5476ac21
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built pyod combo wget
# Installing collected packages: wget, barbar, slicer, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch, shap, copulas, catboost, rtdl, pyod, delu, combo, adbench
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 1.13.1 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed adbench-0.1.11 barbar-0.2.1 catboost-1.2.5 combo-0.1.3 copulas-0.11.0 delu-0.0.23 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 pyod-1.0.0 rtdl-0.0.13 shap-0.46.0 slicer-0.0.8 torch-1.13.1 wget-3.2

# %% [markdown]
# We also need to download the datasets for ADbench

# %%
from adbench.myutils import Utils
utils = Utils() # utility function
# download datasets from the remote github repo
utils.download_datasets(repo='github')

# %% [markdown]
# ## 2. Load and Explore an ADbench Dataset

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pyod.models.knn import KNN  # Example anomaly detector
import shap  # For SHAP values explanation

# %%
# Load a dataset from ADbench
adbench_dir = '/path/to/your/environment/eg/lib/python3.11/site-packages/adbench/datasets/Classical/' # change this to your adbench directory
dataset_name = '2_annthyroid.npz'  # You can change this to another dataset, see https://github.com/Minqi824/ADBench/tree/main/adbench/datasets/Classical
data = np.load(adbench_dir+dataset_name, allow_pickle=True)
X, y = data['X'], data['y']

# %%
# split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(f"Dataset: {dataset_name}")
print(f"Training set shape: {X_train.shape}")
print(f"Test set shape: {X_test.shape}")
# Out:
# Dataset: 2_annthyroid.npz
# Training set shape: (5040, 6)
# Test set shape: (2160, 6)

# %%
# Visualize the data distribution (use a subset if too large)
sns.pairplot(pd.DataFrame(X_train), diag_kind='kde')
plt.show()

# %% [markdown]
# ## 3. Using PyOD for Anomaly Detection

# %%
# Initialize a PyOD model (KNN as an example)
clf = KNN()

# Train the model
clf.fit(X_train)

# Predict anomalies on the test set
y_test_pred = clf.predict(X_test)
y_test_scores = clf.decision_function(X_test)

# %% [markdown]
# ## 4. Evaluating Anomaly Detection Model Performance

# %%
from sklearn.metrics import roc_auc_score, accuracy_score

# Evaluate the model
auc = roc_auc_score(y_test, y_test_scores)
accuracy = accuracy_score(y_test, y_test_pred)

print(f"ROC AUC: {auc:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# ROC AUC: 0.7522
# Accuracy: 0.8861

# %% [markdown]
# ## 5. Visualizing Results

# %%
# Plot ROC Curve
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, y_test_scores)
plt.plot(fpr, tpr, label=f'AUC = {auc:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='best')
plt.show()

# %%
# Visualize anomaly scores
plt.hist(y_test_scores, bins=50)
plt.xlabel('Anomaly Score')
plt.ylabel('Frequency')
plt.title('Anomaly Scores Distribution')
plt.show()

# %%
# Visualize the data distribution (use a subset if too large), coloring true positives, false positives, true negatives, and false negatives
df = pd.DataFrame(X_train)
df['y'] = y_train
df['y_pred'] = clf.predict(X_train)

# %%
def label_outcome(row):
    if row['y'] == 1 and row['y_pred'] == 1:
        return 'TP'  # True Positive
    elif row['y'] == 0 and row['y_pred'] == 1:
        return 'FP'  # False Positive
    elif row['y'] == 0 and row['y_pred'] == 0:
        return 'TN'  # True Negative
    elif row['y'] == 1 and row['y_pred'] == 0:
        return 'FN'  # False Negative

# %%
df['outcome'] = df.apply(label_outcome, axis=1)
df = df.drop(['y', 'y_pred'], axis=1)
df.head()
# Out:
#       0        1      2      3      4      5 outcome
# 0  0.28  0.00208  0.017  0.116  0.101  0.115      TN
# 1  0.74  0.00300  0.012  0.096  0.093  0.103      TN
# 2  0.85  0.00140  0.006  0.124  0.096  0.129      TN
# 3  0.34  0.00680  0.024  0.096  0.104  0.090      FN
# 4  0.46  0.00091  0.024  0.124  0.104  0.118      TN

# %%
# Visualize the data distribution (use a subset if too large), coloring true positives, false positives, true negatives, and false negatives

pp = sns.pairplot(df, diag_kind='kde', hue='outcome',  # color by outcome
                  diag_kws=dict(common_norm=False))  # scale kde independently for each outcome
plt.show()

# %% [markdown]
# ## 6. Explainability with SHAP

# %%
# find index of first true positive
first_tp_index = df[df['outcome'] == 'TP'].index[0]
print(f"Index of the first True Positive: {first_tp_index}")
# Out:
# Index of the first True Positive: 20

# %%
# Fit SHAP explainer and obtain SHAP values for one observation -- TRUE POSITIVE
explainer = shap.explainers.Exact(clf.decision_function, X_train)
shap_values_exact = explainer(np.array([X_train[first_tp_index,]]))
shap.plots.waterfall(shap_values_exact[0])

# %% [markdown]
# # Internal GDL project

# %% [markdown]
# ## *1. How do different unsupervised anomaly detectors perform across different datasets?*
# Limit research to unsupervised anomaly detectors, on the following ADbench datasets:
# * annthyroid,
# * campaign,
# * census,
# * donors, and
# * skin
#
# Evaluate performance of AD methods using AUC-ROC. Keep in mind different methods have different hyperparameters. Optimizing hyperparameters requires cross-validation.
#
# ### Hints
#
# *You may want to subsample datasets to reduce computational load---make sure to stratify on y to preserve class balance of inliers/outliers.*
#
# *While you can run each dataset as a single experiment, it may be more efficient to build a pipeline.*

# %% [markdown]
# ## *2. How consistent are SHAP explanations for different anomaly detectors?*
# Where anomaly detectors agree on predictions, do they give rise to similar SHAP value explanations? How about when they disagree?

# %% [markdown]
# [link text] (https://)## *3. How does missing data impact anomaly detection?*
# Are different anomaly detection algorithms better suited for datasets where there are more missing values?
